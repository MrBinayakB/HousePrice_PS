# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
sns.set(style="white",color_codes=True)

# %%
HouseDS=pd.read_csv("HousePS.csv")
HouseDS.head()
# Out:
#                                                Title  \
# 0  Flat System House On Sale At Budhanikantha : H...
# 1  21 Aana Beautiful House : House For Sale In Bu...
# 2  Beautiful To Floor House : House For Sale In D...
# 3  Modern Architecture Bungalow House : House For...
# 4  Modern Bungalow House : House For Sale In Golf...
#
#                                     Address       City        Price  NewPrice  \
# 0  Budhanikantha, Budhanilkantha, Kathmandu  Kathmandu   90000000.0   90000.0
# 1        Pasikot, Budhanilkantha, Kathmandu  Kathmandu   80000000.0   80000.0
# 2               Dhapasi, Dhapasi, Kathmandu  Kathmandu   70000000.0   70000.0
# 3           baluwatar, Baluwatar, Kathmandu  Kathmandu  130000000.0  130000.0
# 4             Golfutar, Golfutar, Kathmandu  Kathmandu  100000000.0  100000.0
#
#    Bedroom  Bathroom  Floors  Parking  Face    Year Views           Area  \
# 0        6         3     2.0       10  West  2073.0    17   1-0-0-0 Aana
# 1        5         3     2.0        9  East  2073.0    26  0-21-0-0 Aana
# 2        5         3     2.0       12  East  2071.0   154   1-1-0-0 Aana
# 3        6         4     3.0        9  West  2017.0    17  0-10-1-0 Aana
# 4        6         3     2.0       10  East  2070.0    59  0-19-2-0 Aana
#
#                     Road Road Width     Road Type     Build Area  \
# 0  20 Feet / Blacktopped   20 Feet    Blacktopped  18-0-0-0 Aana
# 1  20 Feet / Blacktopped   20 Feet    Blacktopped  0-14-0-0 Aana
# 2  20 Feet / Blacktopped   20 Feet    Blacktopped  10-1-0-0 Aana
# 3  20 Feet / Blacktopped   20 Feet    Blacktopped   0-7-1-0 Aana
# 4  20 Feet / Blacktopped   20 Feet    Blacktopped  0-14-2-0 Aana
#
#          Posted                                          Amenities
# 0  11 hours ago  ['Parking', 'Lawn', 'Garage', 'Frontyard', 'Fe...
# 1  12 hours ago  ['Parking', 'Garage', 'Fencing', 'Frontyard', ...
# 2    2 days ago  ['Parking', 'Lawn', 'Garage', 'Frontyard', 'Fe...
# 3     1 day ago  ['Parking', 'Lawn', 'Garage', 'Frontyard', 'Fe...
# 4    2 days ago  ['Parking', 'Lawn', 'Garage', 'Balcony', 'Back...

# %%
HouseDS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2211 entries, 0 to 2210
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       2211 non-null   object
#  1   Address     2211 non-null   object
#  2   City        2211 non-null   object
#  3   Price       2211 non-null   float64
#  4   NewPrice    2211 non-null   float64
#  5   Bedroom     2211 non-null   int64
#  6   Bathroom    2211 non-null   int64
#  7   Floors      1039 non-null   float64
#  8   Parking     2211 non-null   int64
#  9   Face        2211 non-null   object
#  10  Year        582 non-null    float64
#  11  Views       2211 non-null   object
#  12  Area        2211 non-null   object
#  13  Road        2211 non-null   object
#  14  Road Width  2211 non-null   object
#  15  Road Type   1426 non-null   object
#  16  Build Area  2211 non-null   object
#  17  Posted      2211 non-null   object
#  18  Amenities   2211 non-null   object
# dtypes: float64(4), int64(3), object(12)
# memory usage: 328.3+ KB

# %%
HouseDS.describe()
# Out:
#               Price      NewPrice      Bedroom     Bathroom       Floors  \
# count  2.211000e+03  2.211000e+03  2211.000000  2211.000000  1039.000000
# mean   4.064428e+11  4.064428e+08     2.731796     1.871099     2.824206
# std    7.564268e+12  7.564268e+09     4.174364     2.635836     1.265411
# min    1.500000e+01  1.500000e-02     0.000000     0.000000     0.000000
# 25%    1.300000e+06  1.300000e+03     0.000000     0.000000     2.000000
# 50%    8.000000e+06  8.000000e+03     0.000000     0.000000     3.000000
# 75%    2.650000e+07  2.650000e+04     5.000000     4.000000     3.000000
# max    2.160000e+14  2.160000e+11    95.000000    40.000000    13.000000
#
#            Parking         Year
# count  2211.000000   582.000000
# mean      1.007689  2057.780069
# std       2.094905    26.098577
# min       0.000000  1994.000000
# 25%       0.000000  2020.000000
# 50%       0.000000  2074.000000
# 75%       1.000000  2076.000000
# max      31.000000  2077.000000

# %%
HouseDS["Price"].value_counts()
# Out:
# NewPrice
# 3500.0     35
# 25000.0    33
# 2500.0     32
# 15000.0    30
# 35000.0    29
#            ..
# 24.0        1
# 35200.0     1
# 96000.0     1
# 12.0        1
# 59000.0     1
# Name: count, Length: 407, dtype: int64

# %%
HouseDS.plot(kind="scatter",x="Bedroom",y="Price")
# Out:
# <Axes: xlabel='NewPrice', ylabel='Bedroom'>
